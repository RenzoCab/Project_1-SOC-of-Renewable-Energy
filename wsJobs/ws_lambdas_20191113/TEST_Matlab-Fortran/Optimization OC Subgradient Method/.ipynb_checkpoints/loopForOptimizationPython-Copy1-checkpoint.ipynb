# %%
import numpy
import time

from nsopy.methods.subgradient import SubgradientMethod
from nsopy.loggers import GenericMethodLogger

# Author: Renzo Caballero
# KAUST: King Abdullah University of Science and Technology
# email 1: renzo.caballerorosas@kaust.edu.sa
# email 2: CaballeroRenzo@hotmail.com
# email 3: CaballeroRen@gmail.com
# Website: None
# November 2019; Last revision: 15/11/2019

# %%
def oracle(x):
    
    sft = 0;
    comm = numpy.asarray([x[0]-sft,x[1]-sft,x[2]-sft,x[3]-sft,0,0,0,0,0,0]);
    numpy.savetxt("loopForOpt.csv", comm, delimiter=",");
    done = 0;

    while done == 0:

        time.sleep(20);
        comm = numpy.loadtxt("loopForOpt.csv", delimiter =', ');

        if float(comm[9]) == 1:
            print([comm[0],comm[1],comm[2],comm[3],comm[4],comm[5],comm[6],comm[7],comm[8]]);
            done = 1;
        else:
            print('Waiting for MATLAB...');
            
    f_x_k = comm[4];
    diff_f_xk = [comm[5],comm[6],comm[7],comm[8]];
    
    return 0, f_x_k, numpy.array(diff_f_xk)

def projection_function(x_k):
    if x_k is 0:
        return numpy.array([0,])
    else:
        return numpy.maximum(x_k, 0)

# %%
method = SubgradientMethod(oracle, projection_function, dimension=4, stepsize_0=2, stepsize_rule="1/k", sense='min')
logger = GenericMethodLogger(method)

for iteration in range(100):
    method.step()
# Out:
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.26835, 0.26818, -9.0332, 0.44205, 1.9717, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.26835, 0.26818, -9.0332, 0.4424, 1.9715, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.40253, 0.40227, -9.0405, 0.44239, 1.9737, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.49198, 0.49166, -9.0453, 0.44304, 1.9722, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.55906, 0.55871, -9.049, 0.44247, 1.9767, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.61273, 0.61234, -9.0519, 0.44255, 1.9717, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.65746, 0.65704, -9.0543, 0.44226, 1.9737, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.69579, 0.69535, -9.0564, 0.44232, 1.9689, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.72934, 0.72887, -9.0582, 0.4423, 1.9728, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.75915, 0.75867, -9.0598, 0.44247, 1.9741, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.78599, 0.78549, -9.0613, 0.44308, 1.9718, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.81038, 0.80987, -9.0626, 0.44245, 1.9743, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.83275, 0.83222, -9.0638, 0.44216, 1.9716, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.85339, 0.85285, -9.065, 0.44253, 1.9776, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.87256, 0.872, -9.066, 0.44088, 1.9742, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.89045, 0.88988, -9.067, 0.44233, 1.974, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.90722, 0.90664, -9.0679, 0.4423, 1.9749, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.923, 0.92242, -9.0687, 0.44205, 1.9738, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.93791, 0.93732, -9.0695, 0.44242, 1.9742, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.95204, 0.95143, -9.0703, 0.44268, 1.9715, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.96545, 0.96484, -9.071, 0.44239, 1.9734, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.97823, 0.97761, -9.0717, 0.44247, 1.9758, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.99043, 0.9898, -9.0724, 0.44246, 1.974, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 1.0021, 1.0015, -9.073, 0.44246, 1.9746, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 1.0133, 1.0126, -9.0736, 0.44233, 1.9713, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 1.024, 1.0234, -9.0742, 0.44213, 1.9737, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 1.0343, 1.0337, -9.0748, 0.44231, 1.976, -2.6835, -2.6818]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-eab1b7b32e65> in <module>
#       3
#       4 for iteration in range(100):
# ----> 5     method.step()
#
# ~/anaconda3/lib/python3.7/site-packages/nsopy/methods/base.py in step(self)
#       5
#       6     def step(self):
# ----> 7         self.dual_step()
#
# ~/anaconda3/lib/python3.7/site-packages/nsopy/methods/subgradient.py in dual_step(self)
#      57     def dual_step(self):
#      58         # get subgradient
# ---> 59         self.x_k, self.d_k, diff_d_k = self.oracle(self.lambda_k)
#      60         # log signal to any observers connected
#      61         self.notify_observers()
#
# ~/anaconda3/lib/python3.7/site-packages/nsopy/utils.py in inverted_oracle(lambda_k)
#       6 def invert_oracle_sense(oracle):
#       7     def inverted_oracle(lambda_k):
# ----> 8         x_k, d_k, diff_d_k = oracle(lambda_k)
#       9
#      10         return x_k, -d_k, -diff_d_k
#
# <ipython-input-2-a42ded0cc014> in oracle(x)
#       8     while done == 0:
#       9
# ---> 10         time.sleep(20);
#      11         comm = numpy.loadtxt("loopForOpt.csv", delimiter =', ');
#      12
#
# KeyboardInterrupt:
