# %%
import numpy
import time

from nsopy.methods.subgradient import SubgradientMethod
from nsopy.loggers import GenericMethodLogger

# Author: Renzo Caballero
# KAUST: King Abdullah University of Science and Technology
# email 1: renzo.caballerorosas@kaust.edu.sa
# email 2: CaballeroRenzo@hotmail.com
# email 3: CaballeroRen@gmail.com
# Website: None
# November 2019; Last revision: 18/11/2019

# %%
def oracle(x):
    
    sft = 0;
    comm = numpy.asarray([x[0]-sft,x[1]-sft,x[2]-sft,x[3]-sft,0,0,0,0,0,0]);
    numpy.savetxt("loopForOpt.csv", comm, delimiter=",");
    done = 0;

    while done == 0:

        time.sleep(20);
        comm = numpy.loadtxt("loopForOpt.csv", delimiter =', ');

        if float(comm[9]) == 1:
            print([comm[0],comm[1],comm[2],comm[3],comm[4],comm[5],comm[6],comm[7],comm[8]]);
            done = 1;
        else:
            print('Waiting for MATLAB...');
            
    f_x_k = comm[4];
    diff_f_xk = [comm[5],comm[6],comm[7],comm[8]];
    
    return 0, f_x_k, numpy.array(diff_f_xk)

def projection_function(x_k):
    if x_k is 0:
        return numpy.array([0,])
    else:
        return numpy.maximum(x_k, 0)

# %%
method = SubgradientMethod(oracle, projection_function, dimension=4, stepsize_0=2, stepsize_rule="1/k", sense='min')
logger = GenericMethodLogger(method)

for iteration in range(100):
    method.step()
# Out:
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 0.0, 0.0, -9.0186, 0.44227, 1.9741, -2.6835, -2.6818]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 5.3636, -9.2294, 0.47158, 1.9747, -1.397e-16, -0.28164]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 5.6452, -9.2313, 0.47079, 1.9748, -2.3283e-16, -0.28151]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 5.8329, -9.232, 0.47199, 1.9712, -4.6566e-17, -0.14094]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 5.9034, -9.2322, 0.47103, 1.9724, -4.6566e-17, -0.14091]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 5.9597, -9.2324, 0.46948, 1.9772, -1.8626e-16, -0.14089]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.0067, -9.2326, 0.47063, 1.9726, -3.7253e-16, -0.14087]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.047, -9.2327, 0.47039, 1.9753, -9.3132e-17, -0.14085]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.0822, -9.2328, 0.47426, 1.9723, -9.3132e-17, -0.14083]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.1135, -9.2329, 0.4707, 1.9749, 9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.1416, -9.233, 0.4707, 1.9747, -1.397e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.1672, -9.2331, 0.47174, 1.9665, -9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.1907, -9.2331, 0.47065, 1.9747, -4.6566e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.2123, -9.2332, 0.47078, 1.9716, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.2324, -9.2332, 0.47386, 1.9724, -3.2596e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.2512, -9.2333, 0.47069, 1.9763, -1.8626e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.2688, -9.2334, 0.47143, 1.9766, -3.7253e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.2853, -9.2334, 0.47452, 1.9723, -2.3283e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.301, -9.2335, 0.47076, 1.9724, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.3158, -9.2335, 0.47133, 1.9752, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.3299, -9.2336, 0.4708, 1.9792, -9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.3433, -9.2336, 0.47161, 1.9725, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.3561, -9.2336, 0.47079, 1.9705, -1.8626e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.3683, -9.2336, 0.47165, 1.9721, -1.397e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.38, -9.2337, 0.47103, 1.9724, 9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.3913, -9.2338, 0.47162, 1.9717, -9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4021, -9.2338, 0.47099, 1.9747, 9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4125, -9.2339, 0.47117, 1.9746, -9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4226, -9.2338, 0.47134, 1.974, -9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4323, -9.2339, 0.47164, 1.9764, -9.3132e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4417, -9.2339, 0.47181, 1.9724, -1.8626e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4508, -9.2339, 0.46928, 1.9748, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4596, -9.2339, 0.47101, 1.9752, -3.2596e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4681, -9.234, 0.47922, 1.968, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4764, -9.234, 0.47112, 1.9725, -4.6566e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4844, -9.2339, 0.47088, 1.9753, -0.0, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4922, -9.2339, 0.46918, 1.9725, -1.397e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.4998, -9.2339, 0.47137, 1.9731, -3.7253e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.5072, -9.2339, 0.47109, 1.9709, -4.191e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.5145, -9.2339, 0.46717, 1.9696, -1.397e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.5215, -9.2339, 0.47029, 1.9771, 4.6566e-17, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# [0.0, 0.0, 5.367, 6.5284, -9.2339, 0.47042, 1.9725, -2.794e-16, -0.14074]
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# Waiting for MATLAB...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-8c3708ebb36b> in <module>
#       3
#       4 for iteration in range(100):
# ----> 5     method.step()
#
# ~/anaconda3/lib/python3.7/site-packages/nsopy/methods/base.py in step(self)
#       5
#       6     def step(self):
# ----> 7         self.dual_step()
#
# ~/anaconda3/lib/python3.7/site-packages/nsopy/methods/subgradient.py in dual_step(self)
#      57     def dual_step(self):
#      58         # get subgradient
# ---> 59         self.x_k, self.d_k, diff_d_k = self.oracle(self.lambda_k)
#      60         # log signal to any observers connected
#      61         self.notify_observers()
#
# ~/anaconda3/lib/python3.7/site-packages/nsopy/utils.py in inverted_oracle(lambda_k)
#       6 def invert_oracle_sense(oracle):
#       7     def inverted_oracle(lambda_k):
# ----> 8         x_k, d_k, diff_d_k = oracle(lambda_k)
#       9
#      10         return x_k, -d_k, -diff_d_k
#
# <ipython-input-2-a42ded0cc014> in oracle(x)
#       8     while done == 0:
#       9
# ---> 10         time.sleep(20);
#      11         comm = numpy.loadtxt("loopForOpt.csv", delimiter =', ');
#      12
#
# KeyboardInterrupt:
