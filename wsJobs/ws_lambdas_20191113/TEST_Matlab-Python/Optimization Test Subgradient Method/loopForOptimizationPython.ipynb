# %%
import numpy
import time

from nsopy.methods.subgradient import SubgradientMethod
from nsopy.loggers import GenericMethodLogger

# Author: Renzo Caballero
# KAUST: King Abdullah University of Science and Technology
# email 1: renzo.caballerorosas@kaust.edu.sa
# email 2: CaballeroRenzo@hotmail.com
# email 3: CaballeroRen@gmail.com
# Website: None
# November 2019; Last revision: 14/11/2019

# %%
def oracle(x):
    
    shift = 8;
    comm = numpy.asarray([x[0]-shift,x[1]-shift,0,0,0,0]);
    numpy.savetxt("loopForOpt.csv", comm, delimiter=",");
    done = 0;

    while done == 0:

        time.sleep(1);
        comm = numpy.loadtxt("loopForOpt.csv", delimiter =', ');

        if float(comm[5]) == 1:
            print([comm[0],comm[1],comm[2],comm[3],comm[4]]);
            comm[5] = 0;
            numpy.savetxt("loopForOpt.csv", comm, delimiter=",");
            done = 1;
        else:
            print('Waiting for MATLAB...');
            
    f_x_k = comm[2];
    diff_f_xk = [comm[3],comm[4]];
    
    return 0, f_x_k, numpy.array(diff_f_xk)

def projection_function(x_k):
    if x_k is 0:
        return numpy.array([0,])
    else:
        return numpy.maximum(x_k, 0)

# %%
method = SubgradientMethod(oracle, projection_function, dimension=2, stepsize_0=0.1, stepsize_rule="1/k", sense='min')
logger = GenericMethodLogger(method)

for iteration in range(100):
    method.step()
# Out:
# [-8.0, -8.0, 1030.0, -192.0, -192.0]
# Waiting for MATLAB...
# [11.2, 11.2, 2774.1, 358.4, 358.4]
# Waiting for MATLAB...
# [-6.72, -6.72, 618.17, -134.4, -134.4]
# Waiting for MATLAB...
# [-2.24, -2.24, 26.141, -17.92, -17.92]
# Waiting for MATLAB...
# [-1.792, -1.792, 14.268, -10.752, -10.752]
# Waiting for MATLAB...
# [-1.577, -1.577, 9.9208, -9.4618, -9.4618]
# Waiting for MATLAB...
# [-1.4193, -1.4193, 7.0859, -8.5156, -8.5156]
# Waiting for MATLAB...
# [-1.2976, -1.2976, 5.7352, -5.1904, -5.1904]
# Waiting for MATLAB...
# [-1.2327, -1.2327, 5.0785, -4.9309, -4.9309]
# Waiting for MATLAB...
# [-1.1779, -1.1779, 4.5502, -4.7118, -4.7118]
# Waiting for MATLAB...
# [-1.1308, -1.1308, 4.1151, -4.5233, -4.5233]
# Waiting for MATLAB...
# [-1.0897, -1.0897, 3.7498, -4.3588, -4.3588]
# Waiting for MATLAB...
# [-1.0534, -1.0534, 3.4385, -4.2135, -4.2135]
# Waiting for MATLAB...
# [-1.021, -1.021, 3.1695, -4.0839, -4.0839]
# Waiting for MATLAB...
# [-0.9918, -0.9918, 2.9347, -3.9672, -3.9672]
# Waiting for MATLAB...
# [-0.96535, -0.96535, 2.7276, -3.8614, -3.8614]
# Waiting for MATLAB...
# [-0.94122, -0.94122, 2.5436, -3.7649, -3.7649]
# Waiting for MATLAB...
# [-0.91907, -0.91907, 2.3788, -3.6763, -3.6763]
# Waiting for MATLAB...
# [-0.89865, -0.89865, 2.2303, -3.5946, -3.5946]
# Waiting for MATLAB...
# [-0.87973, -0.87973, 2.0957, -3.5189, -3.5189]
# Waiting for MATLAB...
# [-0.86213, -0.86213, 1.9731, -3.4485, -3.4485]
# Waiting for MATLAB...
# [-0.84571, -0.84571, 1.8609, -3.3829, -3.3829]
# Waiting for MATLAB...
# [-0.83034, -0.83034, 1.7578, -3.3213, -3.3213]
# Waiting for MATLAB...
# [-0.8159, -0.8159, 1.6627, -3.2636, -3.2636]
# Waiting for MATLAB...
# [-0.8023, -0.8023, 1.5747, -3.2092, -3.2092]
# Waiting for MATLAB...
# [-0.78946, -0.78946, 1.493, -3.1578, -3.1578]
# Waiting for MATLAB...
# [-0.77731, -0.77731, 1.4169, -3.1093, -3.1093]
# Waiting for MATLAB...
# [-0.7658, -0.7658, 1.3458, -3.0632, -3.0632]
# Waiting for MATLAB...
# [-0.75486, -0.75486, 1.2792, -3.0194, -3.0194]
# Waiting for MATLAB...
# [-0.74445, -0.74445, 1.2168, -2.9778, -2.9778]
# Waiting for MATLAB...
# [-0.73452, -0.73452, 1.1581, -2.9381, -2.9381]
# Waiting for MATLAB...
# [-0.72504, -0.72504, 1.1028, -2.9002, -2.9002]
# Waiting for MATLAB...
# [-0.71598, -0.71598, 1.0505, -2.8639, -2.8639]
# Waiting for MATLAB...
# [-0.7073, -0.7073, 1.0011, -2.8292, -2.8292]
# Waiting for MATLAB...
# [-0.69898, -0.69898, 0.97715, -1.398, -1.398]
# Waiting for MATLAB...
# [-0.69499, -0.69499, 0.96601, -1.39, -1.39]
# Waiting for MATLAB...
# [-0.69113, -0.69113, 0.95531, -1.3823, -1.3823]
# Waiting for MATLAB...
# [-0.68739, -0.68739, 0.94501, -1.3748, -1.3748]
# Waiting for MATLAB...
# [-0.68377, -0.68377, 0.93509, -1.3675, -1.3675]
# Waiting for MATLAB...
# [-0.68027, -0.68027, 0.92552, -1.3605, -1.3605]
# Waiting for MATLAB...
# [-0.67686, -0.67686, 0.91629, -1.3537, -1.3537]
# Waiting for MATLAB...
# [-0.67356, -0.67356, 0.90737, -1.3471, -1.3471]
# Waiting for MATLAB...
# [-0.67035, -0.67035, 0.89875, -1.3407, -1.3407]
# Waiting for MATLAB...
# [-0.66724, -0.66724, 0.89041, -1.3345, -1.3345]
# Waiting for MATLAB...
# [-0.6642, -0.6642, 0.88233, -1.3284, -1.3284]
# Waiting for MATLAB...
# [-0.66125, -0.66125, 0.87451, -1.3225, -1.3225]
# Waiting for MATLAB...
# [-0.65838, -0.65838, 0.86692, -1.3168, -1.3168]
# Waiting for MATLAB...
# [-0.65558, -0.65558, 0.85956, -1.3112, -1.3112]
# Waiting for MATLAB...
# [-0.65284, -0.65284, 0.85241, -1.3057, -1.3057]
# Waiting for MATLAB...
# [-0.65018, -0.65018, 0.84546, -1.3004, -1.3004]
# Waiting for MATLAB...
# [-0.64758, -0.64758, 0.83871, -1.2952, -1.2952]
# Waiting for MATLAB...
# [-0.64504, -0.64504, 0.83215, -1.2901, -1.2901]
# Waiting for MATLAB...
# [-0.64256, -0.64256, 0.82576, -1.2851, -1.2851]
# Waiting for MATLAB...
# [-0.64013, -0.64013, 0.81954, -1.2803, -1.2803]
# Waiting for MATLAB...
# [-0.63776, -0.63776, 0.81348, -1.2755, -1.2755]
# Waiting for MATLAB...
# [-0.63544, -0.63544, 0.80757, -1.2709, -1.2709]
# Waiting for MATLAB...
# [-0.63317, -0.63317, 0.80182, -1.2663, -1.2663]
# Waiting for MATLAB...
# [-0.63095, -0.63095, 0.7962, -1.2619, -1.2619]
# Waiting for MATLAB...
# [-0.62878, -0.62878, 0.79072, -1.2576, -1.2576]
# Waiting for MATLAB...
# [-0.62664, -0.62664, 0.78537, -1.2533, -1.2533]
# Waiting for MATLAB...
# [-0.62456, -0.62456, 0.78014, -1.2491, -1.2491]
# Waiting for MATLAB...
# [-0.62251, -0.62251, 0.77503, -1.245, -1.245]
# Waiting for MATLAB...
# [-0.6205, -0.6205, 0.77004, -1.241, -1.241]
# Waiting for MATLAB...
# [-0.61853, -0.61853, 0.76516, -1.2371, -1.2371]
# Waiting for MATLAB...
# [-0.6166, -0.6166, 0.76038, -1.2332, -1.2332]
# Waiting for MATLAB...
# [-0.6147, -0.6147, 0.75571, -1.2294, -1.2294]
# Waiting for MATLAB...
# [-0.61284, -0.61284, 0.75114, -1.2257, -1.2257]
# Waiting for MATLAB...
# [-0.61101, -0.61101, 0.74666, -1.222, -1.222]
# Waiting for MATLAB...
# [-0.60921, -0.60921, 0.74228, -1.2184, -1.2184]
# Waiting for MATLAB...
# [-0.60744, -0.60744, 0.73798, -1.2149, -1.2149]
# Waiting for MATLAB...
# [-0.60571, -0.60571, 0.73377, -1.2114, -1.2114]
# Waiting for MATLAB...
# [-0.604, -0.604, 0.72964, -1.208, -1.208]
# Waiting for MATLAB...
# [-0.60233, -0.60233, 0.72559, -1.2047, -1.2047]
# Waiting for MATLAB...
# [-0.60067, -0.60067, 0.72162, -1.2013, -1.2013]
# Waiting for MATLAB...
# [-0.59905, -0.59905, 0.71773, -1.1981, -1.1981]
# Waiting for MATLAB...
# [-0.59745, -0.59745, 0.7139, -1.1949, -1.1949]
# Waiting for MATLAB...
# [-0.59588, -0.59588, 0.71015, -1.1918, -1.1918]
# Waiting for MATLAB...
# [-0.59433, -0.59433, 0.70647, -1.1887, -1.1887]
# Waiting for MATLAB...
# [-0.59281, -0.59281, 0.70285, -1.1856, -1.1856]
# Waiting for MATLAB...
# [-0.59131, -0.59131, 0.69929, -1.1826, -1.1826]
# Waiting for MATLAB...
# [-0.58983, -0.58983, 0.6958, -1.1797, -1.1797]
# Waiting for MATLAB...
# [-0.58837, -0.58837, 0.69237, -1.1767, -1.1767]
# Waiting for MATLAB...
# [-0.58694, -0.58694, 0.689, -1.1739, -1.1739]
# Waiting for MATLAB...
# [-0.58553, -0.58553, 0.68568, -1.1711, -1.1711]
# Waiting for MATLAB...
# [-0.58413, -0.58413, 0.68242, -1.1683, -1.1683]
# Waiting for MATLAB...
# [-0.58276, -0.58276, 0.67921, -1.1655, -1.1655]
# Waiting for MATLAB...
# [-0.5814, -0.5814, 0.67606, -1.1628, -1.1628]
# Waiting for MATLAB...
# [-0.58006, -0.58006, 0.67295, -1.1601, -1.1601]
# Waiting for MATLAB...
# [-0.57875, -0.57875, 0.6699, -1.1575, -1.1575]
# Waiting for MATLAB...
# [-0.57745, -0.57745, 0.66689, -1.1549, -1.1549]
# Waiting for MATLAB...
# [-0.57616, -0.57616, 0.66393, -1.1523, -1.1523]
# Waiting for MATLAB...
# [-0.5749, -0.5749, 0.66101, -1.1498, -1.1498]
# Waiting for MATLAB...
# [-0.57365, -0.57365, 0.65814, -1.1473, -1.1473]
# Waiting for MATLAB...
# [-0.57241, -0.57241, 0.65531, -1.1448, -1.1448]
# Waiting for MATLAB...
# [-0.5712, -0.5712, 0.65253, -1.1424, -1.1424]
# Waiting for MATLAB...
# [-0.56999, -0.56999, 0.64978, -1.14, -1.14]
# Waiting for MATLAB...
# [-0.56881, -0.56881, 0.64708, -1.1376, -1.1376]
# Waiting for MATLAB...
# [-0.56763, -0.56763, 0.64441, -1.1353, -1.1353]
# Waiting for MATLAB...
# [-0.56647, -0.56647, 0.64179, -1.1329, -1.1329]
# Waiting for MATLAB...
# [-0.56533, -0.56533, 0.6392, -1.1307, -1.1307]
